# %%
import os
import sys

import findspark
findspark.init()

from pyspark import SparkContext

sc = SparkContext(master= "local[4]")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-7ad2f768e21a> in <module>
#       7 from pyspark import SparkContext
#       8
# ----> 9 sc = SparkContext(master= "local[4]")
#
# C:\spark\python\pyspark\context.py in __init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls)
#     131                     " note this option will be removed in Spark 3.0")
#     132
# --> 133         SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     134         try:
#     135             self._do_init(master, appName, sparkHome, pyFiles, environment, batchSize, serializer,
#
# C:\spark\python\pyspark\context.py in _ensure_initialized(cls, instance, gateway, conf)
#     330                         " created by %s at %s:%s "
#     331                         % (currentAppName, currentMaster,
# ...

# %%
import pandas as pd

# %%
from pyspark import sql

# %%
df1 = pd.read_csv("C:\Data-Attraper le flamand rose\user-session.csv")
# Out:
#   File "<ipython-input-4-29573ae98431>", line 1
#     df1 = pd.read_csv("C:\Data-Attraper le flamand rose\user-session.csv")
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 32-33: truncated \uXXXX escape

# %%
df1 = pd.read_csv("C:/Data-Attraper le flamand rose/user-session.csv")

# %%
df1
# Out:
#                 timestamp  userSessionId  userId  teamId  assignmentId  \
# 0     2016-05-26 14:47:30           5675     170      90          5423
# 1     2016-05-27 00:06:54           5675     170      90          5423
# 2     2016-05-26 14:43:09           5795     835      39          5300
# 3     2016-05-27 08:06:54           5795     835      39          5300
# 4     2016-05-26 14:47:20           5833     624       2          5529
# ...                   ...            ...     ...     ...           ...
# 9245  2016-06-16 11:06:54          32496    1011     135         17708
# 9246  2016-06-13 09:06:54          33308    1228     135         32502
# 9247  2016-06-16 11:06:54          33308    1228     135         32502
# 9248  2016-06-15 17:06:54          38321     981     135         36067
# 9249  2016-06-16 11:06:54          38321     981     135         36067
#
#      sessionType  teamLevel platformType
# 0          start          1       iphone
# ...

# %%
df2 = df1.drop_duplicates(subset=['userId'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-870235a8b74b> in <module>
# ----> 1 df2 = df1.drop_duplicates(subset=['userId'])
#
# NameError: name 'df1' is not defined

# %%
df1 = pd.read_csv("C:/Data-Attraper le flamand rose/user-session.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-014fe4b460fa> in <module>
# ----> 1 df1 = pd.read_csv("C:/Data-Attraper le flamand rose/user-session.csv")
#
# NameError: name 'pd' is not defined

# %%
import os
import sys

import findspark
findspark.init()

from pyspark import SparkContext

sc = SparkContext(master= "local[4]")

# %%
import pandas as pd

# %%
from pyspark import sql

# %%
df1 = pd.read_csv("C:/Data-Attraper le flamand rose/user-session.csv")

# %%
df1
# Out:
#                 timestamp  userSessionId  userId  teamId  assignmentId  \
# 0     2016-05-26 14:47:30           5675     170      90          5423
# 1     2016-05-27 00:06:54           5675     170      90          5423
# 2     2016-05-26 14:43:09           5795     835      39          5300
# 3     2016-05-27 08:06:54           5795     835      39          5300
# 4     2016-05-26 14:47:20           5833     624       2          5529
# ...                   ...            ...     ...     ...           ...
# 9245  2016-06-16 11:06:54          32496    1011     135         17708
# 9246  2016-06-13 09:06:54          33308    1228     135         32502
# 9247  2016-06-16 11:06:54          33308    1228     135         32502
# 9248  2016-06-15 17:06:54          38321     981     135         36067
# 9249  2016-06-16 11:06:54          38321     981     135         36067
#
#      sessionType  teamLevel platformType
# 0          start          1       iphone
# ...

# %%
df2 = df1.drop_duplicates(subset=['userId'])

# %%
df2
# Out:
#                 timestamp  userSessionId  userId  teamId  assignmentId  \
# 0     2016-05-26 14:47:30           5675     170      90          5423
# 2     2016-05-26 14:43:09           5795     835      39          5300
# 4     2016-05-26 14:47:20           5833     624       2          5529
# 6     2016-05-26 14:37:33           5877     514       2          5528
# 8     2016-05-26 14:36:55           5902    2103       2          5527
# ...                   ...            ...     ...     ...           ...
# 9196  2016-06-15 22:06:54          38722     424     148         37948
# 9226  2016-06-12 20:36:54          32362    1299     110         31888
# 9228  2016-06-13 11:36:54          33499    1564     110         33442
# 9246  2016-06-13 09:06:54          33308    1228     135         32502
# 9248  2016-06-15 17:06:54          38321     981     135         36067
#
#      sessionType  teamLevel platformType
# 0          start          1       iphone
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd 
pinkFlam = pd.read_csv ('C:/Data-Attraper le flamand rose/catchThePinkFlamingo.csv')
pinkFlam = pinkFlam.rename(columns=lambda x: x.strip())

# %%
pinkFlam
# Out:
#       userId  userSessionId  teamLevel platformType  count_gameclicks  \
# 0        812           5648          1      android                69
# 1       1658           5649          1       iphone                31
# 2       1589           5650          1       iphone                26
# 3       1863           5651          1      android                35
# 4        937           5652          1      android                39
# ...      ...            ...        ...          ...               ...
# 4614    1399          37261          6          mac                28
# 4615     248          37491          3       iphone               108
# 4616     981          38321          6       iphone                36
# 4617    1575          38602          3      android                11
# 4618     424          38722          5      android                33
#
#       count_hits  count_buyId  avg_price
# 0              8          NaN        NaN
# 1              5          NaN        NaN
# ...

# %%
print('Samples with Purchases : ' + str(pinkFlam['avg_price'].count()) + 
      'from  the total samples : ' + str(pinkFlam['userId'].count()))
# Out:
# Samples with Purchases : 1411from  the total samples : 4619

# %%
pinkFlam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4619 entries, 0 to 4618
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   userId            4619 non-null   int64
#  1   userSessionId     4619 non-null   int64
#  2   teamLevel         4619 non-null   int64
#  3   platformType      4619 non-null   object
#  4   count_gameclicks  4619 non-null   int64
#  5   count_hits        4619 non-null   int64
#  6   count_buyId       1411 non-null   float64
#  7   avg_price         1411 non-null   float64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 288.8+ KB

# %%
from matplotlib import pyplot
pd.DataFrame.hist(pinkFlam[['avg_price']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000261E2E36448>]],
#       dtype=object)

# %%
plt.title('Correlogram of Pink Flamingo', fontsize=20)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,10), dpi= 80)
sns.heatmap(pinkFlam.corr(), xticklabels=pinkFlam.corr().columns,
            yticklabels=pinkFlam.corr().columns, cmap='RdYlGn', center=0, annot=True)

# %%
plt.figure(figsize=(10,10), dpi= 80)
sns.heatmap(pinkFlam.corr(), xticklabels=pinkFlam.corr().columns,
            yticklabels=pinkFlam.corr().columns, cmap='RdYlGn', center=0, annot=True)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd 
pinkFlam = pd.read_csv ('C:/Data-Attraper le flamand rose/catchThePinkFlamingo.csv')
pinkFlam = pinkFlam.rename(columns=lambda x: x.strip())

# %%
pinkFlam
# Out:
#       userId  userSessionId  teamLevel platformType  count_gameclicks  \
# 0        812           5648          1      android                69
# 1       1658           5649          1       iphone                31
# 2       1589           5650          1       iphone                26
# 3       1863           5651          1      android                35
# 4        937           5652          1      android                39
# ...      ...            ...        ...          ...               ...
# 4614    1399          37261          6          mac                28
# 4615     248          37491          3       iphone               108
# 4616     981          38321          6       iphone                36
# 4617    1575          38602          3      android                11
# 4618     424          38722          5      android                33
#
#       count_hits  count_buyId  avg_price
# 0              8          NaN        NaN
# 1              5          NaN        NaN
# ...

# %%
import os
import sys

import findspark
findspark.init()

from pyspark import SparkContext

sc = SparkContext(master= "local[4]")

# %%
import pandas as pd

# %%
from pyspark import sql

# %%
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(pinkFlam.corr(), xticklabels=pinkFlam.corr().columns,
            yticklabels=pinkFlam.corr().columns, cmap='RdYlGn', center=0, annot=True)
plt.title('Correlogram of Pink Flamingo', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
corr = pinkFlam.corr()
corr
# Out:
#                     userId  userSessionId  teamLevel  count_gameclicks  \
# userId            1.000000       0.030163  -0.002158          0.072707
# userSessionId     0.030163       1.000000   0.765534          0.216295
# teamLevel        -0.002158       0.765534   1.000000         -0.080415
# count_gameclicks  0.072707       0.216295  -0.080415          1.000000
# count_hits        0.073603       0.221440  -0.058090          0.959317
# count_buyId      -0.045570       0.219281   0.270753         -0.010759
# avg_price        -0.015360      -0.024990   0.025648         -0.030101
#
#                   count_hits  count_buyId  avg_price
# userId              0.073603    -0.045570  -0.015360
# userSessionId       0.221440     0.219281  -0.024990
# teamLevel          -0.058090     0.270753   0.025648
# count_gameclicks    0.959317    -0.010759  -0.030101
# count_hits          1.000000    -0.000002   0.013463
# count_buyId        -0.000002     1.000000  -0.017451
# ...

# %%
impute_grps = pinkFlam.pivot_table(values=["avg_price"], index=["platformType","count_gameclicks","count_hits"],
                                   aggfunc=len) # default aggfunc=np.mean
impute_grps.head()
# Out:
#                                           avg_price
# platformType count_gameclicks count_hits
# android      1                0                 2.0
#              2                0                 3.0
#                               1                 1.0
#              3                0                 3.0
#                               1                 1.0

# %%
sns.catplot(x="avg_price",y="platformType",kind='box',data=pinkFlam)

# %%
pinkFlam.replace("", np.nan, inplace=True)
pinkFlam = pinkFlam[np.isfinite(pinkFlam['count_buyId'])]
pinkFlam['user_category'] = np.where(pinkFlam['avg_price']> 5, 'HighRollers', 'PennyPinchers')
pinkFlam.head()
# Out:
#     userId  userSessionId  teamLevel platformType  count_gameclicks  \
# 4      937           5652          1      android                39
# 11    1623           5659          1       iphone               129
# 13      83           5661          1      android               102
# 17     121           5665          1      android                39
# 18     462           5666          1      android                90
#
#     count_hits  count_buyId  avg_price  user_category
# 4            0          1.0        1.0  PennyPinchers
# 11           9          1.0       10.0    HighRollers
# 13          14          1.0        5.0  PennyPinchers
# 17           4          1.0        3.0  PennyPinchers
# 18          10          1.0        3.0  PennyPinchers

# %%
sns.scatterplot(x='platformType',y='count_gameclicks',hue='user_category',data=pinkFlam)

# %%
pinkFlam = pinkFlam.drop(['userId' , 'userSessionId' , 'avg_price'], axis = 1)
pinkFlam.head()
# Out:
#     teamLevel platformType  count_gameclicks  count_hits  count_buyId  \
# 4           1      android                39           0          1.0
# 11          1       iphone               129           9          1.0
# 13          1      android               102          14          1.0
# 17          1      android                39           4          1.0
# 18          1      android                90          10          1.0
#
#     user_category
# 4   PennyPinchers
# 11    HighRollers
# 13  PennyPinchers
# 17  PennyPinchers
# 18  PennyPinchers

# %%
import seaborn as sns
sns.countplot(x="platformType", hue="user_category", data=pinkFlam)
